# %% [markdown]
# # STARtrack Capstone Notebook
#
# End-to-end walkthrough of the Interview Practice Coach pipeline.
# Demonstrates: assessment, progression analysis, and scoresheet generation
# using the three pre-built user tracks (user_a, user_b, user_c).

# %%
# Setup
import os
from dotenv import load_dotenv
load_dotenv()

from skills.assessment import assess_answer
from skills.progression import save_session, analyze_progression
from skills.scoresheet import generate_scoresheet
from skills.guardrails import semantic_gate, validate_session

# %% [markdown]
# ## 1. Assess a Single Attempt

# %%
transcript = open('question_1/user_c/attempt_3.txt').read()
print(transcript)

# %%
# TODO: call semantic_gate, then assess_answer
# gate_result = semantic_gate(transcript)
# assessment = assess_answer(transcript, question_id='question_1', user_id='user_c', attempt_number=3)

# %% [markdown]
# ## 2. Analyze Progression (user_c)

# %%
# TODO: call analyze_progression after at least 2 attempts are saved
# narrative = analyze_progression(user_id='user_c')

# %% [markdown]
# ## 3. Generate Scoresheet PDF

# %%
# TODO: call generate_scoresheet
# pdf_path = generate_scoresheet(history=[], narrative=None, user_id='user_c', attempt_number=3)
